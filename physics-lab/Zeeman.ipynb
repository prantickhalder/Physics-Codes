# %%
#Magnetic Field vs Current
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from scipy import stats
rng = np.random.default_rng()

b = [155, 277, 402, 523, 639, 754, 859.5, 966, 1062, 1164, 1252.5, 1338.5, 1414, 1479.5, 1533.5]
cur = np.arange(0.25, 4, 0.25)

x = cur
y = b

res = stats.linregress(x, y)
plt.plot(x, y, '.', label='original data')
plt.plot(x, res.intercept + res.slope*x, 'r', label='fitted line')
plt.xlabel('Current(A)')
plt.ylabel('Magnetic Field(Gauss * 10)')
plt.legend()
plt.show()

sp.stats.linregress(x, y)
# Out:
# LinregressResult(slope=400.70714285714286, intercept=119.88571428571424, rvalue=0.9954364150340933, pvalue=1.1859918816819128e-14, stderr=10.654029647213688, intercept_stderr=24.216932022295733)
