# %%
#(3) To estimate P(2 < X < 5):

import numpy as np

ini = 2
fin = 5
h = 3

x = np.linspace(0, np.inf, num = n)
def f(x):
  f = np.exp(-((x-3)**2)/512)/(16*np.sqrt(2*np.pi))
  return f


def trap(h):

  s = 0
  y = np.zeros((n))

  for i in range(ini, (fin+1)):
    y[i] = np.array(f(i))

  for i in range(n):
    if (i > ini and i < (fin-1)):
      s += y[i]
      #print(i,s)
  ar = (h/2)*(y[0] + 2*s + y[-1])

  return ar

print('Area using trapezoidal rule is:', trap(h))
# Out:
# Area using trapezoidal rule is: 0.07480167757526864
